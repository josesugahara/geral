# %%
import numpy as np
import pandas as pd
import geopy.distance
import haversine as hs
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
df = pd.read_csv('vetorizado_limpo.csv')
df = df.set_index('Cliente')
df
# Out:
#          LEITE UHT INT EDGE BETA 1L  BL FERMENTADA MORANGO BAT GUT 900G  \
# Cliente
# 1000045                           0                                   0
# 1000052                           0                                   0
# 1000062                           0                                   0
# 1000077                           1                                   0
# 1000098                           1                                   1
# ...                             ...                                 ...
# 1250012                           0                                   0
# 2000198                           1                                   0
# 2000199                           0                                   0
# 2001705                           1                                   0
# 2001766                           0                                   0
#
#          REQUEIJAO CREMOSO BETA 200G  CREME DE LEITE BETA 200G  \
# Cliente
# 1000045                            0                         0
# 1000052                            0                         0
# 1000062                            0                         0
# 1000077                            0                         1
# 1000098                            1                         0
# ...                              ...                       ...
# 1250012                            0                         0
# 2000198                            0                         0
# 2000199                            0                         0
# 2001705                            0                         0
# 2001766                            0                         0
#
#          IOG INT MOR E BAN/MAC BET KIDS BDJ 540G  LEITE CONDENSADO BETA 395G
# Cliente
# 1000045                                        0                           0
# 1000052                                        0                           0
# 1000062                                        0                           0
# 1000077                                        0                           1
# 1000098                                        1                           1
# ...                                          ...                         ...
# 1250012                                        0                           0
# 2000198                                        0                           0
# 2000199                                        0                           0
# 2001705                                        0                           0
# 2001766                                        0                           0
#
# [3788 rows x 6 columns]

# %%
df = df.astype(bool)
df
# Out:
#          LEITE UHT INT EDGE BETA 1L  BL FERMENTADA MORANGO BAT GUT 900G  \
# Cliente
# 1000045                       False                               False
# 1000052                       False                               False
# 1000062                       False                               False
# 1000077                        True                               False
# 1000098                        True                                True
# ...                             ...                                 ...
# 1250012                       False                               False
# 2000198                        True                               False
# 2000199                       False                               False
# 2001705                        True                               False
# 2001766                       False                               False
#
#          REQUEIJAO CREMOSO BETA 200G  CREME DE LEITE BETA 200G  \
# Cliente
# 1000045                        False                     False
# 1000052                        False                     False
# 1000062                        False                     False
# 1000077                        False                      True
# 1000098                         True                     False
# ...                              ...                       ...
# 1250012                        False                     False
# 2000198                        False                     False
# 2000199                        False                     False
# 2001705                        False                     False
# 2001766                        False                     False
#
#          IOG INT MOR E BAN/MAC BET KIDS BDJ 540G  LEITE CONDENSADO BETA 395G
# Cliente
# 1000045                                    False                       False
# 1000052                                    False                       False
# 1000062                                    False                       False
# 1000077                                    False                        True
# 1000098                                     True                        True
# ...                                          ...                         ...
# 1250012                                    False                       False
# 2000198                                    False                       False
# 2000199                                    False                       False
# 2001705                                    False                       False
# 2001766                                    False                       False
#
# [3788 rows x 6 columns]

# %%
frequent_itemsets = apriori(df, min_support=0.07, use_colnames=True)
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.7)

# %%
rules
# Out:
#                                            antecedents  \
# 0                        (REQUEIJAO CREMOSO BETA 200G)
# 1                 (BL FERMENTADA MORANGO BAT GUT 900G)
# 2            (IOG INT MOR E BAN/MAC BET KIDS BDJ 540G)
# 3            (IOG INT MOR E BAN/MAC BET KIDS BDJ 540G)
# 4                         (LEITE CONDENSADO BETA 395G)
# ..                                                 ...
# 105  (LEITE UHT INT EDGE BETA 1L, IOG INT MOR E BAN...
# 106  (LEITE UHT INT EDGE BETA 1L, LEITE CONDENSADO ...
# 107  (LEITE CONDENSADO BETA 395G, IOG INT MOR E BAN...
# 108  (REQUEIJAO CREMOSO BETA 200G, IOG INT MOR E BA...
# 109  (LEITE CONDENSADO BETA 395G, IOG INT MOR E BAN...
#
#                                            consequents  antecedent support  \
# 0                 (BL FERMENTADA MORANGO BAT GUT 900G)            0.527455
# 1                        (REQUEIJAO CREMOSO BETA 200G)            0.530095
# 2                 (BL FERMENTADA MORANGO BAT GUT 900G)            0.410771
# 3                        (REQUEIJAO CREMOSO BETA 200G)            0.410771
# 4                           (CREME DE LEITE BETA 200G)            0.386748
# ..                                                 ...                 ...
# 105  (LEITE CONDENSADO BETA 395G, REQUEIJAO CREMOSO...            0.120116
# 106  (REQUEIJAO CREMOSO BETA 200G, CREME DE LEITE B...            0.112988
# 107  (REQUEIJAO CREMOSO BETA 200G, BL FERMENTADA MO...            0.115628
# 108  (LEITE CONDENSADO BETA 395G, BL FERMENTADA MOR...            0.122492
# 109  (BL FERMENTADA MORANGO BAT GUT 900G, CREME DE ...            0.113516
#
#      consequent support   support  confidence      lift  leverage  conviction
# 0              0.530095  0.405755    0.769269  1.451191  0.126154    2.036595
# 1              0.527455  0.405755    0.765438  1.451191  0.126154    2.014586
# 2              0.530095  0.340285    0.828406  1.562750  0.122538    2.738472
# 3              0.527455  0.328141    0.798843  1.514524  0.111478    2.349137
# 4              0.471753  0.319166    0.825256  1.749339  0.136716    3.022977
# ..                  ...       ...         ...       ...       ...         ...
# 105            0.241816  0.086589    0.720879  2.981103  0.057543    2.716328
# 106            0.278511  0.086589    0.766355  2.751614  0.055121    3.087973
# 107            0.405755  0.086589    0.748858  1.845593  0.039672    2.366175
# 108            0.237064  0.086589    0.706897  2.981875  0.057551    2.602957
# 109            0.271647  0.086589    0.762791  2.808019  0.055753    3.070506
#
# [110 rows x 9 columns]

# %%
cluster = rules[ (rules['lift'] >= 2.2) & (rules['confidence'] >= 0.70) ]

# %%
rules.to_excel("basket.xlsx")

# %%
cluster
# Out:
#                                                antecedents  \
# 2006517  (IOG INT MOR E BAN/MAC BET KIDS BDJ 540G, LEIT...
# 2122139  (IOG INT MOR E BAN/MAC BET KIDS BDJ 540G, MANT...
# 2295558  (LEITE UHT INT BETA 1L, MANTEIGA C/ SAL BETA 2...
# 2585306  (LEITE UHT INT BETA 1L, MANTEIGA C/ SAL BETA 2...
# 3016181  (LEITE UHT INT BETA 1L, MANTEIGA C/ SAL BETA 2...
# ...                                                    ...
# 4166065  (IOG INT MOR E BAN/MAC BET KIDS BDJ 540G, BL U...
# 4166098  (IOG INT MOR E BAN/MAC BET KIDS BDJ 540G, BL U...
# 4166232  (BEB LAC UHT CHOCOLATE BETANIA KIDS 200ML, BL ...
# 4166273  (BEB LAC UHT CHOCOLATE BETANIA KIDS 200ML, BL ...
# 4166793  (IOG INT MOR E BAN/MAC BET KIDS BDJ 540G, BL U...
#
#                                                consequents  \
# 2006517  (LEITE UHT DESNT EDGE BETA 1L, IOG GARR PARC D...
# 2122139  (LEITE UHT DESNT EDGE BETA 1L, REQUEIJAO CREMO...
# 2295558  (REQUEIJAO CREMOSO BETA 200G, LEITE UHT DESNT ...
# 2585306  (LEITE UHT DESNT EDGE BETA 1L, BEB LAC UHT CHO...
# 3016181  (REQUEIJAO CREMOSO BETA 200G, LEITE UHT DESNT ...
# ...                                                    ...
# 4166065  (BEB LAC UHT CHOCOLATE BETANIA KIDS 200ML, IOG...
# 4166098  (BEB LAC UHT CHOCOLATE BETANIA KIDS 200ML, MAN...
# 4166232  (IOG INT MOR E BAN/MAC BET KIDS BDJ 540G, REQU...
# 4166273  (IOG INT MOR E BAN/MAC BET KIDS BDJ 540G, IOG ...
# 4166793  (BEB LAC UHT CHOCOLATE BETANIA KIDS 200ML, IOG...
#
#          antecedent support  consequent support   support  confidence  \
# 2006517            0.085938            0.256696  0.071057    0.826840
# 2122139            0.093006            0.248512  0.075149    0.808000
# 2295558            0.091518            0.250000  0.074033    0.808943
# 2585306            0.087798            0.240699  0.070312    0.800847
# 3016181            0.094122            0.250000  0.076265    0.810277
# ...                     ...                 ...       ...         ...
# 4166065            0.096354            0.259301  0.079985    0.830116
# 4166098            0.099330            0.241443  0.079985    0.805243
# 4166232            0.097842            0.254836  0.079985    0.817490
# 4166273            0.096726            0.253348  0.079985    0.826923
# 4166793            0.096726            0.243676  0.079985    0.826923
#
#              lift  leverage  conviction
# 2006517  3.221080  0.048997    4.292578
# 2122139  3.251353  0.052036    3.914000
# 2295558  3.235772  0.051153    3.925532
# 2585306  3.327168  0.049180    3.812658
# 3016181  3.241107  0.052734    3.953125
# ...           ...       ...         ...
# 4166065  3.201365  0.055000    4.360026
# 4166098  3.335122  0.056002    3.894896
# 4166232  3.207904  0.055051    4.082876
# 4166273  3.263978  0.055480    4.313988
# 4166793  3.393541  0.056415    4.369874
#
# [100 rows x 9 columns]
